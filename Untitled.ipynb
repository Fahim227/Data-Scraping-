# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')
data
# Out:
#         Unnamed: 0  time  Class Distance   GNG       CourseName         date  \
# 0                0  6:55    4.0       7f  Good          Sandown   1 Aug 2018
# 1                0  6:55    4.0       7f  Good          Sandown   1 Aug 2018
# 2                0  6:55    4.0       7f  Good          Sandown   1 Aug 2018
# 3                0  6:55    4.0       7f  Good          Sandown   1 Aug 2018
# 4                0  6:55    4.0       7f  Good          Sandown   1 Aug 2018
# ...            ...   ...    ...      ...   ...              ...          ...
# 105339           0  6:05    NaN       2m  Good  Kilbeggan (IRE)  19 Jul 2019
# 105340           0  6:05    NaN       2m  Good  Kilbeggan (IRE)  19 Jul 2019
# 105341           0  6:05    NaN       2m  Good  Kilbeggan (IRE)  19 Jul 2019
# 105342           0  6:05    NaN       2m  Good  Kilbeggan (IRE)  19 Jul 2019
# 105343           0  6:05    NaN       2m  Good  Kilbeggan (IRE)  19 Jul 2019
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0             0
# time                   0
# Class              33547
# Distance               0
# GNG                    0
# CourseName             0
# date                   0
# pos                    0
# draw                   0
# horse_name             0
# SP                     0
# trainer                0
# jokey                  0
# age                    0
# weight                 0
# Official_rating        0
# TS                     0
# RPR                    0
# winning_time           0
# Price                  0
# url                    0
# dtype: int64

# %%
is_NaN = data.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = data[row_has_NaN]
rows_with_NaN.head()['url'].values
# Out:
# array(['https://www.racingpost.com/results/196/roscommon/2021-08-16/791330',
#        'https://www.racingpost.com/results/196/roscommon/2021-08-16/791330',
#        'https://www.racingpost.com/results/196/roscommon/2021-08-16/791330',
#        'https://www.racingpost.com/results/196/roscommon/2021-08-16/791330',
#        'https://www.racingpost.com/results/196/roscommon/2021-08-16/791330'],
#       dtype=object)
